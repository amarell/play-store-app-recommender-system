# %%
import numpy as np
import pandas as pd
from surprise import KNNWithMeans
from surprise import Dataset, Reader, SVD
from surprise.model_selection import GridSearchCV

# %%
df = pd.read_csv("user-item-100k-cleaned.csv")
df_raw = pd.read_csv("cleaned_top_5k.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110187 entries, 0 to 110186
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  110187 non-null  int64
#  1   user_id     110187 non-null  int64
#  2   app_id      110187 non-null  int64
#  3   rating      110187 non-null  int64
# dtypes: int64(4)
# memory usage: 3.4 MB

# %%
reader = Reader(rating_scale=(1, 5))

# The columns must correspond to user id, item id and ratings (in that order).
data = Dataset.load_from_df(df[["user_id", "app_id", "rating"]], reader)

# %%
param_grid = {
    "n_epochs": [5, 10],
    "lr_all": [0.002, 0.005],
    "reg_all": [0.4, 0.6]
}
gs = GridSearchCV(SVD, param_grid, measures=["rmse", "mae"], cv=3)

gs.fit(data)

print(gs.best_score["rmse"])
print(gs.best_params["rmse"])
# Out:
# 1.2968420571623511
# {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.6}

# %%
svd = SVD(verbose=True, n_epochs=5, lr_all=0.002, reg_all=0.6)
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    1.2954  1.2986  1.2942  1.2961  0.0019
# MAE (testset)     1.1248  1.1269  1.1226  1.1248  0.0017
# Fit time          0.26    0.29    0.29    0.28    0.01
# Test time         0.25    0.35    0.22    0.27    0.05
# {'test_rmse': array([1.29542948, 1.29860994, 1.29421247]),
#  'test_mae': array([1.12481379, 1.12685095, 1.12258766]),
#  'fit_time': (0.2616913318634033, 0.2869088649749756, 0.29254603385925293),
#  'test_time': (0.2512173652648926, 0.345078706741333, 0.21838903427124023)}

# %%
user_ratings['app_id']
# Out:
# 0      538
# 1      137
# 2        3
# 3        0
# 4        4
# 5        2
# 6       18
# 7     2554
# 8       89
# 9       16
# 10       1
# Name: app_id, dtype: int64

# %%
apps = []

for x in user_ratings['app_id'].values:
    apps.append(df_raw.iloc[x, :])
    
applications = pd.DataFrame(apps)
applications
# Out:
#       Unnamed: 0                                           App Name  \
# 538       159431                                                OLX
# 137       981879                                         Temple Run
# 3         881403                                            YouTube
# 0         385470                                 WhatsApp Messenger
# 4         244319                         Garena Free Fire - Rampage
# 2        2222701                                           Facebook
# 18       2068486                                        8 Ball Pool
# 2554     1528026    TikFans - Boost Followers and Likes for Tik Tok
# 89       2295599                                 eFootball PES 2021
# 16        962538  Spotify: Listen to podcasts & find music you love
# 1         304824                                          Instagram
#
#                           App Id                 Category  Rating  \
# 538                  com.olx.olx                 Shopping     4.5
# 137         com.imangi.templerun                   Arcade     4.1
# 3     com.google.android.youtube  Video Players & Editors     4.4
# 0                   com.whatsapp            Communication     4.0
# 4             com.dts.freefireth                   Action     4.2
# 2            com.facebook.katana                   Social     2.3
# 18    com.miniclip.eightballpool                   Sports     4.4
# 2554            com.tikfans3.www                    Tools     4.8
# 89               jp.konami.pesam                   Sports     4.4
# 16             com.spotify.music            Music & Audio     4.4
# 1          com.instagram.android                   Social     3.8
#
#       Rating Count        Installs  Minimum Installs  Maximum Installs  Free  \
# 538      1464302.0     50,000,000+      5.000000e+07          91818447  True
# 137      4831552.0    500,000,000+      5.000000e+08         625467333  True
# 3      112440547.0  5,000,000,000+      5.000000e+09        9766230924  True
# 0      138557570.0  5,000,000,000+      5.000000e+09        6265637751  True
# 4       89177097.0    500,000,000+      5.000000e+08         976536041  True
# 2      117850066.0  5,000,000,000+      5.000000e+09        6782619635  True
# 18      21754025.0    500,000,000+      5.000000e+08         747308036  True
# 2554      328647.0      1,000,000+      1.000000e+06           1828455  True
# 89       6782902.0    100,000,000+      1.000000e+08         100156361  True
# 16      22752840.0  1,000,000,000+      1.000000e+09        1033938669  True
# 1      120206190.0  1,000,000,000+      1.000000e+09        3559871277  True
#
#       ...  Size     Minimum Android  Developer Website      Released  \
# 538   ...  21.0          4.1 and up                  1   Sep 7, 2010
# 137   ...  46.0          4.4 and up                  1  Mar 26, 2012
# 3     ...  19.2  Varies with device                  1  Oct 20, 2010
# 0     ...  19.2  Varies with device                  1  Oct 18, 2010
# 4     ...  19.2          4.1 and up                  1   Dec 7, 2017
# 2     ...  19.2  Varies with device                  1  Jun 16, 2021
# 18    ...  67.0          4.4 and up                  1  Jan 23, 2013
# 2554  ...  34.0          5.0 and up                  1  Jul 19, 2020
# 89    ...  95.0          5.0 and up                  1  May 23, 2017
# 16    ...  19.2  Varies with device                  1  May 27, 2014
# 1     ...  19.2  Varies with device                  1   Apr 3, 2012
#
#       Last Updated Content Rating Privacy Policy Ad Supported  \
# 538   Jun 15, 2021           Teen              1         True
# 137   Apr 26, 2021       Everyone              1         True
# 3     Jun 16, 2021           Teen              1         True
# 0     Jun 09, 2021       Everyone              1        False
# 4     Jun 04, 2021     Mature 17+              1        False
# 2     Jun 16, 2021           Teen              1         True
# 18    Jun 07, 2021       Everyone              1         True
# 2554  Feb 14, 2021           Teen              1         True
# 89    Jun 09, 2021       Everyone              1         True
# 16    Jun 10, 2021           Teen              1         True
# 1     Jun 14, 2021           Teen              1         True
#
#       In App Purchases  Editors Choice
# 538              False           False
# 137               True           False
# 3                False           False
# 0                False            True
# 4                 True            True
# 2                 True           False
# 18                True            True
# 2554              True           False
# 89                True            True
# 16               False           False
# 1                 True            True
#
# [11 rows x 22 columns]

# %%
df_raw.iloc[5, :]
# Out:
# Unnamed: 0                                            2095852
# App Name             Messenger – Text and Video Chat for Free
# App Id                                      com.facebook.orca
# Category                                        Communication
# Rating                                                    4.0
# Rating Count                                       78563229.0
# Installs                                       5,000,000,000+
# Minimum Installs                                 5000000000.0
# Maximum Installs                                   5054312355
# Free                                                     True
# Price                                                     0.0
# Currency                                                  USD
# Size                                                     19.2
# Minimum Android                            Varies with device
# Developer Website                                           1
# Released                                         Jan 30, 2014
# Last Updated                                     Jun 14, 2021
# Content Rating                                       Everyone
# Privacy Policy                                              1
# Ad Supported                                            False
# In App Purchases                                         True
# Editors Choice                                           True
# Name: 5, dtype: object

# %%
for i in range(0, user_ratings.values.shape[0]):
    
    
    print(user_ratings.iloc[i, 2])
# Out:
# 538
# 137
# 3
# 0
# 4
# 2
# 18
# 2554
# 89
# 16
# 1

# %%
def get_ratings_by_user(user_id):
    user_ratings = df[df['user_id'] == user_id]
    
    print(user_ratings)
    
    apps = []

    for x in user_ratings['app_id'].values:
        apps.append(df_raw.iloc[x, :])

    applications = pd.DataFrame(apps)
    applications["users_given_rating"] = user_ratings['rating'].values
    
    return applications

# %%
get_ratings_by_user(1).head()
# Out:
#     Unnamed: 0  user_id  app_id  rating
# 0            0        1     538       1
# 1            1        1     137       1
# 2            2        1       3       5
# 3            3        1       0       2
# 4            4        1       4       4
# 5            5        1       2       4
# 6            6        1      18       5
# 7            7        1    2554       5
# 8            8        1      89       4
# 9            9        1      16       5
# 10          10        1       1       5
#      Unnamed: 0                    App Name                      App Id  \
# 538      159431                         OLX                 com.olx.olx
# 137      981879                  Temple Run        com.imangi.templerun
# 3        881403                     YouTube  com.google.android.youtube
# 0        385470          WhatsApp Messenger                com.whatsapp
# 4        244319  Garena Free Fire - Rampage          com.dts.freefireth
#
#                     Category  Rating  Rating Count        Installs  \
# 538                 Shopping     4.5     1464302.0     50,000,000+
# 137                   Arcade     4.1     4831552.0    500,000,000+
# 3    Video Players & Editors     4.4   112440547.0  5,000,000,000+
# 0              Communication     4.0   138557570.0  5,000,000,000+
# 4                     Action     4.2    89177097.0    500,000,000+
#
#      Minimum Installs  Maximum Installs  Free  ...     Minimum Android  \
# 538      5.000000e+07          91818447  True  ...          4.1 and up
# 137      5.000000e+08         625467333  True  ...          4.4 and up
# 3        5.000000e+09        9766230924  True  ...  Varies with device
# 0        5.000000e+09        6265637751  True  ...  Varies with device
# 4        5.000000e+08         976536041  True  ...          4.1 and up
#
#     Developer Website      Released  Last Updated  Content Rating  \
# 538                 1   Sep 7, 2010  Jun 15, 2021            Teen
# 137                 1  Mar 26, 2012  Apr 26, 2021        Everyone
# 3                   1  Oct 20, 2010  Jun 16, 2021            Teen
# 0                   1  Oct 18, 2010  Jun 09, 2021        Everyone
# 4                   1   Dec 7, 2017  Jun 04, 2021      Mature 17+
#
#     Privacy Policy Ad Supported In App Purchases  Editors Choice  \
# 538              1         True            False           False
# 137              1         True             True           False
# 3                1         True            False           False
# 0                1        False            False            True
# 4                1        False             True            True
#
#      users_given_rating
# 538                   1
# 137                   1
# 3                     5
# 0                     2
# 4                     4
#
# [5 rows x 23 columns]

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)
# Out:
# Processing epoch 0
# Processing epoch 1
# Processing epoch 2
# Processing epoch 3
# Processing epoch 4

# %%
svd.predict(uid=1, iid=100)
# Out:
# Prediction(uid=1, iid=100, r_ui=None, est=3.4710672420146698, details={'was_impossible': False})

# %%
def predict_rating(user_id, app_id, model):
    prediction = model.predict(uid=user_id, iid=app_id)
    return prediction.est

# %%
def get_recommendations_for_user(user_id, number_of_recommendations=5, threshold=3.7):
    appIds = np.arange(0,5000)
    # shuffle the appIds to introduce some randomness
    random.shuffle(appIds)
    
    recommendations = []

    for i in range(0, len(appIds)):
        res = predict_rating(user_id, appIds[i], svd)
        if(res > threshold):
            if appIds[i] not in recommendations:
                recommendations.append(appIds[i])
                if len(recommendations) == number_of_recommendations: 
                    return recommendations
    
    
    print("You need to lower the threshold...")
    return []

# %%
def get_app_metadata(app_id):
    return df_raw.iloc[app_id, :]

# %%
get_recommendations_for_user(1)
# Out:
# [2624, 303, 4334, 1238, 1694]

# %%
def generate_recommendation_dataframe(ids):
    apps = []
    
    for x in ids:
        apps.append(get_app_metadata(x))
        
    return pd.DataFrame(apps)

# %%
generate_recommendation_dataframe(get_recommendations_for_user(1))
# Out:
#       Unnamed: 0                                          App Name  \
# 126      1921617  Canva: Graphic Design, Video Collage, Logo Maker
# 2932     1831211                        Buddy.ai: English for kids
# 2093     1764789                                            Serasa
# 4382     1573155                                            냥코 대전쟁
# 1065     1365443     Viki: Stream Asian Drama, Movies and TV Shows
#
#                                 App Id       Category  Rating  Rating Count  \
# 126                   com.canva.editor   Art & Design     4.7     5213141.0
# 2932  ai.mybuddy.talkingflashcards_new      Education     4.7      285745.0
# 2093  br.com.serasaexperian.consumidor        Finance     4.4      398743.0
# 4382          jp.co.ponos.battlecatskr         Casual     4.1      181364.0
# 1065                  com.viki.android  Entertainment     4.2      785834.0
#
#           Installs  Minimum Installs  Maximum Installs  Free  ...   Size  \
# 126   100,000,000+       100000000.0         134619454  True  ...   32.0
# 2932    5,000,000+         5000000.0           7350905  True  ...  144.0
# 2093   10,000,000+        10000000.0          30521607  True  ...   61.0
# 4382    5,000,000+         5000000.0           8047321  True  ...  146.0
# 1065   10,000,000+        10000000.0          41903321  True  ...   19.2
#
#          Minimum Android  Developer Website      Released  Last Updated  \
# 126           5.0 and up                  1  Nov 27, 2017  Jun 16, 2021
# 2932          7.0 and up                  1  Aug 20, 2019  Jun 08, 2021
# 2093          5.0 and up                  1  Mar 20, 2019  Jun 10, 2021
# 4382          5.0 and up                  1  May 20, 2021  May 20, 2021
# 1065  Varies with device                  1   Mar 4, 2012  Jun 14, 2021
#
#      Content Rating Privacy Policy Ad Supported  In App Purchases  \
# 126        Everyone              1        False              True
# 2932       Everyone              1        False              True
# 2093       Everyone              1        False             False
# 4382   Everyone 10+              1         True              True
# 1065           Teen              1         True              True
#
#       Editors Choice
# 126             True
# 2932           False
# 2093           False
# 4382           False
# 1065            True
#
# [5 rows x 22 columns]

# %%
class AppRecommenderSystem:
    
    def __init__(self, ratings_dataset, app_metadata, model):
        self._ratings = ratings_dataset
        self._app_metadata = app_metadata
        self._model = model
        
    def _predict_rating(self, user_id, app_id):
        prediction = self._model.predict(uid=user_id, iid=app_id)
        return prediction.est
    
    def _get_app_metadata(self, app_id):
        return self._app_metadata.iloc[app_id, :]
        
    def _generate_recommendations(self, user_id, number_of_recommendations=5, threshold=3.7):
        appIds = np.arange(0, df_raw.shape[0])
        # shuffle the appIds to introduce some randomness
        random.shuffle(appIds)
        
        recommendations = []
        
        for i in range(0, len(appIds)):
            res = self._predict_rating(user_id, appIds[i])
            if(res > threshold):
                if appIds[i] not in recommendations:
                    recommendations.append(appIds[i])
                    if len(recommendations) == number_of_recommendations: 
                        return recommendations

    
        print("You need to lower the threshold...")
        return []
    
    def _generate_recommendations_dataframe(self, ids):
        apps = []
    
        for x in ids:
            apps.append(self._get_app_metadata(x))

        return pd.DataFrame(apps)
    
    def recommend(self, user_id, number_of_recommendations=5, threshold=3.7):
        result = self._generate_recommendations_dataframe(self._generate_recommendations(user_id, number_of_recommendations, threshold))
        
        return result
        
    def get_user_ratings(self, user_id):
        user_ratings = self._ratings[self._ratings['user_id'] == user_id]

        apps = []

        for x in user_ratings['app_id'].values:
            apps.append(self._app_metadata.iloc[x, 1])

        applications = pd.DataFrame(apps)
        applications["users_given_rating"] = user_ratings['rating'].values

        return applications

# %%
app_recommender = AppRecommenderSystem(df, df_raw, svd)

# %%
app_recommender.recommend(1, 2, 3.7)
# Out:
#       Unnamed: 0             App Name                           App Id  \
# 3788     1888200            Wort Guru     com.wordgames.wordconnect.de
# 1525      709861  Block! Hexa Puzzle™  com.bitmango.go.blockhexapuzzle
#
#      Category  Rating  Rating Count     Installs  Minimum Installs  \
# 3788     Word     4.6      215439.0   5,000,000+         5000000.0
# 1525   Puzzle     3.9      546861.0  50,000,000+        50000000.0
#
#       Maximum Installs  Free  ...  Size Minimum Android  Developer Website  \
# 3788           7760932  True  ...  81.0      4.4 and up                  1
# 1525          89941865  True  ...  69.0      4.4 and up                  1
#
#           Released  Last Updated Content Rating Privacy Policy Ad Supported  \
# 3788  Apr 26, 2017  May 24, 2021           Teen              1         True
# 1525  Apr 25, 2016  May 03, 2021       Everyone              1         True
#
#       In App Purchases  Editors Choice
# 3788              True           False
# 1525              True           False
#
# [2 rows x 22 columns]

# %%
app_recommender.get_user_ratings(1)
# Out:
#                                                     0  users_given_rating
# 0                                                 OLX                   1
# 1                                          Temple Run                   1
# 2                                             YouTube                   5
# 3                                  WhatsApp Messenger                   2
# 4                          Garena Free Fire - Rampage                   4
# 5                                            Facebook                   4
# 6                                         8 Ball Pool                   5
# 7     TikFans - Boost Followers and Likes for Tik Tok                   5
# 8                                  eFootball PES 2021                   4
# 9   Spotify: Listen to podcasts & find music you love                   5
# 10                                          Instagram                   5
