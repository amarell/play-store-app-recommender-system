# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./../Google-Playstore.csv")
df.head()
# Out:
#                                             App Name  \
# 0                                            Gakondo
# 1                                Ampere Battery Info
# 2                                             Vibook
# 3  Smart City Trichy Public Service Vehicles 17UC...
# 4                                            GROW.me
#
#                        App Id       Category  Rating  Rating Count Installs  \
# 0         com.ishakwe.gakondo      Adventure     0.0           0.0      10+
# 1  com.webserveis.batteryinfo          Tools     4.4          64.0   5,000+
# 2        com.doantiepvien.crm   Productivity     0.0           0.0      50+
# 3     cst.stJoseph.ug17ucs548  Communication     5.0           5.0      10+
# 4        com.horodyski.grower          Tools     0.0           0.0     100+
#
#    Minimum Installs  Maximum Installs  Free  Price  ...  \
# 0              10.0                15  True    0.0  ...
# 1            5000.0              7662  True    0.0  ...
# ...

# %%
df.describe(include='O')
# Out:
#            App Name               App Id   Category Installs Currency  \
# count       2312942              2312944    2312944  2312837  2312809
# unique      2177944              2312944         48       22       15
# top     Tic Tac Toe  com.ishakwe.gakondo  Education     100+      USD
# freq            382                    1     241090   443368  2311548
#
#                       Size Minimum Android   Developer Id  \
# count              2312748         2306414        2312911
# unique                1657             154         758371
# top     Varies with device      4.1 and up  Subsplash Inc
# freq                 74777          604465           5422
#
#                 Developer Website       Developer Email      Released  \
# count                     1552109               2312913       2241891
# unique                     810440                950456          4158
# top     http://www.subsplash.com/  support@classplus.co  Jun 16, 2020
# ...

# %%
df.drop(['App Id','Developer Website','Developer Email','Developer Id','Privacy Policy'], axis=1, inplace=True)
df.head()
# Out:
#                                             App Name       Category  Rating  \
# 0                                            Gakondo      Adventure     0.0
# 1                                Ampere Battery Info          Tools     4.4
# 2                                             Vibook   Productivity     0.0
# 3  Smart City Trichy Public Service Vehicles 17UC...  Communication     5.0
# 4                                            GROW.me          Tools     0.0
#
#    Rating Count Installs  Minimum Installs  Maximum Installs  Free  Price  \
# 0           0.0      10+              10.0                15  True    0.0
# 1          64.0   5,000+            5000.0              7662  True    0.0
# 2           0.0      50+              50.0                58  True    0.0
# 3           5.0      10+              10.0                19  True    0.0
# 4           0.0     100+             100.0               478  True    0.0
#
# ...

# %%
# top 10 categories by count
sns.set(font_scale=1.2)
plt.figure(figsize=(15,10))
sns.countplot(x=df[df['Category'].isin(top_10_categories)]['Category'])
plt.plot()
# Out:
# []

# %%
top_10_categories = list(df['Category'].value_counts(normalize=True).head(10).index)

# %%
top_10_android_versions = df['Minimum Android'].value_counts(normalize=True).head(10)

top_10_android_versions.values
# Out:
# array([0.26208001, 0.17212781, 0.16922851, 0.07825221, 0.06652795,
#        0.05028282, 0.0389904 , 0.02843245, 0.02570527, 0.02003717])

# %%
#plt.scatter(df['Maximum Installs'], df['Rating Count'])
plt.figure(figsize=(15,10))
sns.scatterplot(data=df[(df['Category'].isin(top_10_categories)) & (df['Rating'] != 0)], x="Rating", y="Rating Count", hue="Category")
plt.plot()
# Out:
# []

# %%
colors = sns.color_palette('pastel')[0:10]

#create pie chart
plt.figure(figsize=(15,10))
plt.pie(top_10_android_versions.values, labels = top_10_android_versions.index, colors = colors, autopct='%.0f%%')
plt.show()

# %%
sns.set(font_scale=2)
plt.figure(figsize=(60,40))
sns.countplot(x=df['Installs'])
plt.plot()
# Out:
# []

# %%
# top 10 most popular apps and number of ratings and number of installations

rating = df.sort_values(by="Rating Count", ascending=False).head(10)
rating.head(10)
# Out:
#                                          App Name                 Category  \
# 385470                         WhatsApp Messenger            Communication
# 304824                                  Instagram                   Social
# 2222701                                  Facebook                   Social
# 881403                                    YouTube  Video Players & Editors
# 244319                 Garena Free Fire - Rampage                   Action
# 2095852  Messenger – Text and Video Chat for Free            Communication
# 423997                             Clash of Clans                 Strategy
# 58082                      PUBG MOBILE - Traverse                   Action
# 65037                                      TikTok                   Social
# 1830962                             Google Photos              Photography
#
#          Rating  Rating Count        Installs  Minimum Installs  \
# 385470      4.0   138557570.0  5,000,000,000+      5.000000e+09
# ...

# %%
max_installs = df.sort_values(by="Maximum Installs", ascending=False).head(10)

# %%
min_installs.head(10)
# Out:
#                                  App Name                 Category  Rating  \
# 2155096              Google Play services                    Tools     4.2
# 944254       Google Chrome: Fast & Secure            Communication     4.1
# 925338                           Hangouts            Communication     4.0
# 2222701                          Facebook                   Social     2.3
# 1060335             Google Text-to-Speech                    Tools     4.1
# 1733042  Google Maps - Navigate & Explore           Travel & Local     3.8
# 881403                            YouTube  Video Players & Editors     4.4
# 1830962                     Google Photos              Photography     4.5
# 893676                       Google Drive             Productivity     4.3
# 2099458                             Gmail            Communication     4.2
#
#          Rating Count         Installs  Minimum Installs  Maximum Installs  \
# ...

# %%
plt.figure(figsize=(35, 15))
sns.barplot(data=max_installs, x="App Name", y="Maximum Installs")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(35, 15))
sns.set(font_scale=2)
sns.barplot(data=rating, x="App Name", y="Rating Count")
plt.plot()
# Out:
# []

# %%
#create pie chart
sns.set(font_scale=1)
plt.figure(figsize=(15,10))
plt.pie(df['Content Rating'].value_counts(normalize=True).values, labels = df['Content Rating'].value_counts(normalize=True).index, colors = colors, autopct='%0.2f%%', explode=[0.1,0.2,0.3,0.2,0.5,0.1])
plt.show()

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Mature 17+', 'Everyone 10+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
#create pie chart
sns.set(font_scale=1.6)
plt.figure(figsize=(15,10))
plt.pie(df['Free'].value_counts(normalize=True).values, labels = ['Free', 'Not Free'], colors = colors, autopct='%0.2f%%')
plt.show()
